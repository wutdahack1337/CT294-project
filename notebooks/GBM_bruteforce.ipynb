# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor

# %%
training_df = pd.read_csv("../datasets/training.csv")
training_df.set_index("date", inplace=True)

X_train = training_df.iloc[:,1:]
y_train = training_df.Appliances
training_df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# 2016-01-11 17:50:00          50      40  19.890000  46.026667  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:00:00         110       0  25.600000  47.193333  25.968571
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3     T4       RH_4  ...  \
# ...

# %%
testing_df = pd.read_csv("../datasets/testing.csv")
testing_df.set_index("date", inplace=True)
X_test = testing_df.iloc[:, 1:]
y_test = testing_df.Appliances
testing_df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 18:50:00         580      60  20.066667  46.396667  19.426667
# 2016-01-11 19:00:00         430      50  20.133333  48.000000  19.566667
# 2016-01-11 19:10:00         250      40  20.260000  52.726667  19.730000
# 2016-01-11 19:30:00         100      10  20.566667  53.893333  20.033333
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 15:00:00          60       0  25.500000  45.933333  26.277143
# 2016-05-27 15:30:00          80       0  25.500000  45.590000  26.100000
# 2016-05-27 16:30:00         220       0  25.426667  46.060000  26.000000
# 2016-05-27 17:10:00          90       0  25.533333  46.860000  25.978000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# ...

# %%
n_trees   = []
rmse_list = []

n = 1;
while (n <= 900):
    print(n)
    n_trees.append(n)
    
    model = GradientBoostingRegressor(n_estimators=n, max_depth=5, random_state=1337, verbose=1)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, preds))
    rmse_list.append(rmse)

    n += (1 + (n//30));
# Out:
# 1
#       Iter       Train Loss   Remaining Time
#          1       10109.6321            0.00s
# 2
#       Iter       Train Loss   Remaining Time
#          1       10109.6321            0.12s
#          2        9755.4868            0.00s
# 3
#       Iter       Train Loss   Remaining Time
#          1       10109.6321            0.23s
#          2        9755.4868            0.12s
#          3        9455.9143            0.00s
# 4
#       Iter       Train Loss   Remaining Time
#          1       10109.6321            0.34s
#          2        9755.4868            0.23s
#          3        9455.9143            0.12s
#          4        9188.0192            0.00s
# 5
#       Iter       Train Loss   Remaining Time
#          1       10109.6321            0.46s
#          2        9755.4868            0.35s
#          3        9455.9143            0.23s
#          4        9188.0192            0.12s
#          5        8955.7233            0.00s
# 6
# ...

# %%
plt.figure(figsize=(16, 9))
plt.xlabel("Số lượng cây", fontsize=16)
plt.xticks(fontsize=13)
plt.ylabel("RMSE", fontsize=16)
plt.yticks(fontsize=13)

plt.scatter(n_trees, rmse_list, s=90)
plt.savefig("../fig/GBM_fig7_1.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
while (n <= 1200):
    print(n)
    n_trees.append(n)
    
    model = GradientBoostingRegressor(n_estimators=n, max_depth=5, random_state=1337, verbose=1)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, preds))
    rmse_list.append(rmse)

    n += (1 + (n//30));
# Out:
# 913
#       Iter       Train Loss   Remaining Time
#          1       10109.6321            1.77m
#          2        9755.4868            1.78m
#          3        9455.9143            1.77m
#          4        9188.0192            1.77m
#          5        8955.7233            1.76m
#          6        8726.4781            1.76m
#          7        8575.7405            1.76m
#          8        8382.4735            1.76m
#          9        8223.3896            1.76m
#         10        8087.5579            1.76m
#         20        6879.9282            1.74m
#         30        6274.6938            1.72m
#         40        5904.8203            1.68m
#         50        5528.7326            1.66m
#         60        5233.2313            1.63m
#         70        4987.3108            1.61m
#         80        4762.9485            1.59m
#         90        4567.3121            1.57m
#        100        4353.8619            1.56m
#        200        3052.6623            1.43m
# ...

# %%
plt.figure(figsize=(16, 9))
plt.xlabel("Số lượng cây", fontsize=16)
plt.xticks(fontsize=13)
plt.ylabel("RMSE", fontsize=16)
plt.yticks(fontsize=13)

plt.scatter(n_trees, rmse_list, s=60)
plt.savefig("../fig/GBM_fig7_2.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
while (n <= 1500):
    print(n)
    n_trees.append(n)
    
    model = GradientBoostingRegressor(n_estimators=n, max_depth=5, random_state=1337, verbose=1)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, preds))
    rmse_list.append(rmse)

    n += (1 + (n//30));
# Out:
# 1231
#       Iter       Train Loss   Remaining Time
#          1       10109.6321            2.50m
#          2        9755.4868            2.49m
#          3        9455.9143            2.50m
#          4        9188.0192            2.51m
#          5        8955.7233            2.49m
#          6        8726.4781            2.48m
#          7        8575.7405            2.48m
#          8        8382.4735            2.49m
#          9        8223.3896            2.49m
#         10        8087.5579            2.49m
#         20        6879.9282            2.46m
#         30        6274.6938            2.43m
#         40        5904.8203            2.38m
#         50        5528.7326            2.35m
#         60        5233.2313            2.32m
#         70        4987.3108            2.30m
#         80        4762.9485            2.27m
#         90        4567.3121            2.25m
#        100        4353.8619            2.23m
#        200        3052.6623            2.07m
# ...

# %%
plt.figure(figsize=(16, 9))
plt.xlabel("Số lượng cây", fontsize=16)
plt.xticks(fontsize=13)
plt.ylabel("RMSE", fontsize=16)
plt.yticks(fontsize=13)

plt.scatter(n_trees, rmse_list, s=39)
plt.savefig("../fig/GBM_fig7_3.png", dpi=300, bbox_inches="tight")
plt.show()
